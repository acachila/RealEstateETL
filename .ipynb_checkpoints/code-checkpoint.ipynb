# %%
import pandas as pd
from datetime import datetime
import datetime as dt

# %%
data = pd.read_csv("Zip_MedianListingPricePerSqft_AllHomes.csv")
data.head()
# Out:
#    RegionName      City State                             Metro  \
# 0       60657   Chicago    IL          Chicago-Naperville-Elgin
# 1       10023  New York    NY       New York-Newark-Jersey City
# 2       77494      Katy    TX  Houston-The Woodlands-Sugar Land
# 3       60614   Chicago    IL          Chicago-Naperville-Elgin
# 4       77449      Katy    TX  Houston-The Woodlands-Sugar Land
#
#         CountyName  SizeRank   2010-01-01   2010-02-01   2010-03-01  \
# 0      Cook County         1          NaN          NaN          NaN
# 1  New York County         2  1191.765980  1163.301399  1163.301399
# 2    Harris County         3    98.166570    97.829055    97.784810
# 3      Cook County         4   348.570652   333.333148   332.450000
# 4    Harris County         5    61.400155    61.367128    62.054079
#
#     2010-04-01  ...   2018-09-01   2018-10-01   2018-11-01   2018-12-01  \
# 0          NaN  ...   343.492135   340.136054   346.207235   342.962963
# 1  1280.719614  ...  1569.371728  1557.215571  1578.648136  1618.496983
# 2    98.313705  ...   120.706053   120.451902   121.186249   121.057029
# 3   324.812500  ...   441.850100   445.966381   458.715596   453.636364
# 4    62.600321  ...    94.026341    94.402120    94.064390    94.727009
#
#     2019-01-01   2019-02-01   2019-03-01   2019-04-01   2019-05-01  \
# 0   332.792332   332.792332   336.801963   344.290657   352.911765
# 1  1611.805556  1515.831135  1483.791601  1498.333333  1537.692308
# 2   121.477406   121.330627   122.126437   123.043276   122.149837
# 3   444.500000   443.467712   444.207534   449.245940   453.667054
# 4    95.628415    96.011817    97.432721    97.798428    98.268601
#
#     2019-06-01
# 0   352.777778
# 1  1513.017608
# 2   122.387407
# 3   457.500874
# 4    98.488055
#
# [5 rows x 120 columns]

# %%
# start = input("start: ")
# end = input("end: ")
start = "2015-2-1"
end = "2015-6-1"
dates = pd.DataFrame({"md": pd.date_range(start=start, end=end)})
# dates["md"] = dates["md"].dt.strftime("%Y-%m-%d")
months = dates["md"].dt.strftime("%Y-%m")
months = months.unique()
months
# Out:
# array(['2015-02', '2015-03', '2015-04', '2015-05', '2015-06'],
#       dtype=object)

# %%
# start = input("start: ")
# end = input("end: ")
start = "2015-2-1"
end = "2015-6-1"
start = datetime.strptime(start,'%Y-%m-%d')
end = datetime.strptime(end,'%Y-%m-%d')
start = datetime.strftime(start,'%Y-%m-%d')
end = datetime.strftime(end,'%Y-%m-%d')
df = data[["RegionName","City","State","Metro","CountyName",start,end]]
df["diff"] = df[end]/df[start]
df.sort_values("diff",ascending=False)
# Out:
# C:\Users\DQ\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#        RegionName                 City State  \
# 6393        29070  Batesburg-Leesville    SC
# 10201       46511               Culver    IN
# 7885        46534                 Knox    IN
# 8981        49240           Grass Lake    MI
# 4901        45224           Cincinnati    OH
# 10542       55760             McGregor    MN
# 6439        45640              Jackson    OH
# 6968        62522              Decatur    IL
# 1806         7307          Jersey City    NJ
# 3041        16602              Altoona    PA
# 296         58103                Fargo    ND
# 2910        21212            Baltimore    MD
# 9911        16915          Coudersport    PA
# 10895       84719           Brian Head    UT
# 6522        73118        Oklahoma City    OK
# 10831                    Corpus Christi            Nueces County         NaN
# 10833                       Glens Falls            Warren County         NaN
# 10837                            Hudson          Columbia County         NaN
# 10839                               NaN  Kenai Peninsula Borough         NaN
# 10840                               NaN             Barry County         NaN
# 10845                       Port Lavaca           Calhoun County         NaN
# 10847                               NaN          Delaware County         NaN
# 10848              Beaumont-Port Arthur            Hardin County         NaN
# 10852                               NaN              Hyde County         NaN
# 10854                               NaN             Avery County         NaN
# 10856                            Madera            Madera County         NaN
# 10858                        Pittsfield         Berkshire County         NaN
# 10859       New York-Newark-Jersey City           Suffolk County         NaN
# 10862       New York-Newark-Jersey City             Ocean County         NaN
# 10865                         Galesburg              Knox County         NaN
# 10867                               NaN          Cleburne County         NaN
# 10869                  Kill Devil Hills              Dare County         NaN
# 10870                            Bangor         Penobscot County         NaN
# 10871                               NaN           Lincoln County         NaN
# 10872  Riverside-San Bernardino-Ontario    San Bernardino County         NaN
# 10873                               NaN         Aroostook County         NaN
# 10881            Denver-Aurora-Lakewood              Park County         NaN
# 10885                          Bay City         Matagorda County         NaN
# 10887                               NaN              Cook County         NaN
# 10888                         Flagstaff          Coconino County         NaN
# 10890                               NaN         Alleghany County         NaN
# 10892                               NaN            Apache County         NaN
# 10894                               NaN         Tillamook County         NaN
# 10896                  Kill Devil Hills              Dare County         NaN
# 10899                        Orangeburg        Orangeburg County         NaN
#
#        2015-06-01      diff
# 6393   121.510550  1.389026
# 10201  158.913614  1.373511
# 7885    81.226903  1.373136
# 8981   126.514400  1.369554
# 4901    70.807751  1.344755
# 10542  208.125000  1.344036
# 6439    81.483405  1.334941
# 6968    84.047001  1.319231
# 1806   271.090112  1.313134
# 3041    71.400511  1.311955
# 296    150.716846  1.307203
# 2910   187.721519  1.304242
# 9911   111.111111  1.303229
# 10895  128.828008  1.301841
# 6522   113.320079  1.299470
# 675    177.500000  1.293906
# 8065    98.674431  1.275474
# 9246   148.015873  1.269397
# 6026   283.230569  1.263055
# 5529   394.762846  1.261388
# 3007   241.345660  1.261293
# 2282   209.452202  1.256719
# 7460    61.154856  1.255344
# 10283  138.747100  1.254692
# 10009   71.189168  1.254213
# 448    120.194066  1.251991
# 2154   140.394040  1.249057
# 2162    78.861122  1.247889
# 8155    72.636816  1.243437
# 5744    70.991082  1.243106
# ...           ...       ...
# 10831         NaN       NaN
# 10833  127.221318       NaN
# 10837         NaN       NaN
# 10839         NaN       NaN
# 10840         NaN       NaN
# 10845         NaN       NaN
# 10847         NaN       NaN
# 10848         NaN       NaN
# 10852         NaN       NaN
# 10854         NaN       NaN
# 10856         NaN       NaN
# 10858         NaN       NaN
# 10859         NaN       NaN
# 10862         NaN       NaN
# 10865         NaN       NaN
# 10867         NaN       NaN
# 10869         NaN       NaN
# 10870         NaN       NaN
# 10871         NaN       NaN
# 10872         NaN       NaN
# 10873         NaN       NaN
# 10881         NaN       NaN
# 10885         NaN       NaN
# 10887  212.209302       NaN
# 10888         NaN       NaN
# 10890         NaN       NaN
# 10892         NaN       NaN
# 10894         NaN       NaN
# 10896         NaN       NaN
# 10899         NaN       NaN
#
# [10900 rows x 8 columns]
